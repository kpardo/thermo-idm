# %%
# %load_ext autoreload
# %autoreload 2
from astropy import units as u
from astropy import constants as const
import numpy as np
from matplotlib import pyplot as plt

import cluster as c

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cluster = c.Cluster(radius=1*u.Mpc, mass=1.e14*u.Msun, vel_disp=1000*u.km/u.s, bh_mass=1.e10*u.Msun)

# %%
cluster.plot_sigma0_vs_m_chi(n=[0,-2,-4],region=True, save=False)
