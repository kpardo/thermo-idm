            'M200':galwcls[:][18]}

units = {'sig500': u.km/u.s,
            'M500': u.Msun,
            'r200': u.Mpc,
            'sig200': u.km/u.s,
            'M200': u.Msun, }

# %%
cls_table = QTable(cls_data, units=units)

# %%
cls_table
# Out:
# <QTable length=1800>
#   sig500         M500          r200      sig200         M200
#   km / s       solMass         Mpc       km / s       solMass
#  float64       float64       float64    float64       float64
# --------- ----------------- ---------- --------- ------------------
# 1132.3392 950649090000000.0  1.7588447  1042.086 1354718300000000.0
# 1007.6484 639463590000000.0  1.5113488 926.75761  894721140000000.0
# 992.56078 624866900000000.0    1.54485 932.60305  875729550000000.0
# 863.31423 530946780000000.0  1.4534098 881.24884  770246600000000.0
# 858.50327 606589610000000.0  1.4489923 842.65332  758855720000000.0
# 934.17466 361477570000000.0    1.43097 886.46345  733230760000000.0
#       ...               ...        ...       ...                ...
#  307.6751  25382889000000.0 0.53672518 280.27435   38122360000000.0
# 360.63167  18407031000000.0 0.54382244 330.15092   38021286000000.0
# 294.11717  29265465000000.0 0.53257971 325.52783   37987333000000.0
# 368.78647  23567170000000.0 0.53372752 298.36618   37962802000000.0
#   303.704  28182719000000.0 0.53934928 327.58401   37866089000000.0
# 292.17797  23228212000000.0 0.53678028 257.67623   37843010000000.0

# %%
cls_table['sig500']
# Out:
# <Quantity [1132.3392 , 1007.6484 ,  992.56078, ...,  368.78647,  303.704  ,
#             292.17797] km / s>

# %%
i = 1
test_cluster = Cluster(
    cls_table['r200'][i], 
    cls_table['M200'][i], 
    cls_table['sig200'][i], 
    m500=cls_table['M500'][i])
test_cluster.plot_sigma0_vs_m_chi()
plt.title('fx=1')
# Out:
# Text(0.5, 1.0, 'fx=1')

# %%
test_cluster.agn_heating_rate()
# Out:
# <Quantity 1.19917629e+53 GeV / s>

# %%
test_cluster.radiative_cooling_rate()
# Out:
# 0

# %%
test_cluster.plot_T_chi_vs_m_chi()
test_cluster.plot_T_chi_vs_m_chi(f_chi = 0.1, m_psi=0.1*u.GeV)
plt.loglog(test_cluster.m_chi, test_cluster.baryon_temp * np.ones(100), label='baryon temp')
plt.title('Tx vs mx vs Tb')
plt.legend()

# %%
test_cluster.plot_sigma0_vs_m_chi(f_chi = [0.1], m_psi=[0.1*u.GeV], n=[0,-2,-4])

# %%
test_cluster.plot_sigma0_vs_m_chi(f_chi = [1, 0.1, 0.01], m_psi=[0.1*u.GeV], n=[0])

# %%
np.min(test_cluster.sigma0(f_chi = 0.1, m_psi=0.1*u.GeV, n=-4)) #
# Out:
# WARNING: function 'min' is not known to astropy's Quantity. Will run it anyway, hoping it will treat ndarray subclasses correctly. Please raise an issue at https://github.com/astropy/astropy/issues.  [astropy.units.quantity]
# <Quantity 3.51479767e-28 cm2>

# %%
clusters = [Cluster(cls_table['r200'][i], cls_table['M200'][i], cls_table['sig200'][i], m500=cls_table['M500'][i]) for i in range(5)]
[cluster.plot_sigma0_vs_m_chi(f_chi = [0.1], m_psi=[0.1*u.GeV]) for cluster in clusters]
# Out:
# [None, None, None, None, None]

# %%
clusters[0].radiative_cooling_rate()
# Out:
# 0

# %%
clusters[0].plot_sigma0_vs_m_chi(f_chi = [0.1], m_psi=[0.1*u.GeV], n=[-4])
clusters[1].plot_sigma0_vs_m_chi(f_chi = [0.1], m_psi=[0.1*u.GeV], n=[-4])

# %%
r200_avg = np.mean(cls_table['r200'])
M200_avg = np.mean(cls_table['M200'])
sig200_avg = np.mean(cls_table['sig200'])
M500_avg = np.mean(cls_table['M500'])

# %%
r200_avg, M200_avg, sig200_avg, M500_avg
# Out:
# (<Quantity 0.7455313 Mpc>,
#  <Quantity 1.21360536e+14 solMass>,
#  <Quantity 429.34263199 km / s>,
#  <Quantity 8.50139992e+13 solMass>)

# %%
cls_avg = Cluster(r200_avg, M200_avg, sig200_avg, m500=M500_avg)

# %%
cls_avg.baryon_temp, cls_avg.n_e, (cls_avg.volume).to(u.cm**3)
# Out:
# (<Quantity 1.92440032e-06 GeV>,
#  <Quantity 0.00028291 1 / cm3>,
#  <Quantity 5.09962078e+73 cm3>)

# %%
cls_avg.plot_sigma0_vs_m_chi(n=[0,-2,-4])
cls_avg.m500
# Out:
# <Quantity 8.50139992e+13 solMass>

# %%
cls_avg.plot_sigma0_vs_m_chi(f_chi=[0.1], n=[0,-2,-4])

# %%
cls_avg.plot_sigma0_vs_m_chi(f_chi=[1, 0.1, 0.01], n=[0])

# %%
cls_avg.plot_sigma0_vs_m_chi(f_chi=[1, 0.1, 0.01], n=[-2])

# %%
cls_avg.plot_sigma0_vs_m_chi(f_chi=[1, 0.1, 0.01], n=[-4])

# %%
i=2
L_cluster = Cluster(cls_table['r200'][i], cls_table['M200'][i], cls_table['sig200'][i], m500=cls_table['M500'][i], v500=cls_table['sig500'][i])

# %%
L_cluster.luminosity()
# Out:
# <Quantity 3.50864343e+55 GeV / s>

# %%
cls_avg.baryon_temp
# Out:
# <Quantity 1.92440032e-06 GeV>

# %%
cls_avg.virial_temperature()
# Out:
# <Quantity [2.33696681e-11, 2.81488480e-11, 3.39053871e-11, 4.08391587e-11,
#            4.91909113e-11, 5.92506268e-11, 7.13675897e-11, 8.59625145e-11,
#            1.03542153e-10, 1.24716890e-10, 1.50221935e-10, 1.80942853e-10,
#            2.17946307e-10, 2.62517098e-10, 3.16202774e-10, 3.80867361e-10,
#            4.58756085e-10, 5.52573328e-10, 6.65576530e-10, 8.01689287e-10,
#            9.65637585e-10, 1.16311389e-09, 1.40097480e-09, 1.68747910e-09,
#            2.03257455e-09, 2.44824325e-09, 2.94891766e-09, 3.55198176e-09,
#            4.27837460e-09, 5.15331736e-09, 6.20718900e-09, 7.47658112e-09,
#            9.00556843e-09, 1.08472391e-08, 1.30655378e-08, 1.57374866e-08,
#            1.89558583e-08, 2.28323985e-08, 2.75017048e-08, 3.31259008e-08,
#            3.99002647e-08, 4.80600101e-08, 5.78884523e-08, 6.97268458e-08,
#            8.39862326e-08, 1.01161715e-07, 1.21849643e-07, 1.46768327e-07,
#            1.76782969e-07, 2.12935712e-07, 2.56481819e-07, 3.08933259e-07,
#            3.72111204e-07, 4.48209263e-07, 5.39869644e-07, 6.50274898e-07,
#            7.83258416e-07, 9.43437535e-07, 1.13637385e-06, 1.36876633e-06,
#            1.64868389e-06, 1.98584558e-06, 2.39195803e-06, 2.88112191e-06,
#            3.47032155e-06, 4.18001459e-06, 5.03484237e-06, 6.06448546e-06,
#            7.30469420e-06, 8.79853003e-06, 1.05978606e-05, 1.27651606e-05,
#            1.53756811e-05, 1.85200623e-05, 2.23074806e-05, 2.68694394e-05,
#            3.23643349e-05, 3.89829559e-05, 4.69551084e-05, 5.65575944e-05,
#            6.81238226e-05, 8.20553855e-05, 9.88360024e-05, 1.19048315e-04,
#            1.43394117e-04, 1.72718721e-04, 2.08040311e-04, 2.50585291e-04,
#            3.01830870e-04, 3.63556352e-04, 4.37904913e-04, 5.27458018e-04,
#            6.35325050e-04, 7.65251272e-04, 9.21747866e-04, 1.11024857e-03,
#            1.33729833e-03, 1.61078057e-03, 1.94019090e-03, 2.33696681e-03] GeV>
